# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Read xlxs file
df = pd.read_excel('C:/Users/matth/OneDrive/Desktop/DA/Personal Projects/data_cleaning/career_dataset_large.xlsx')
df.head(10)
# Out:
#   Education Level    Specialization                                   Skills  \
# 0      Bachelor's           Finance  Counseling, MS Office, Machine Learning
# 1    Intermediate           Science                    Accounting, MS Office
# 2        Master's          Business           Accounting, SQL, Data Analysis
# 3      Bachelor's  Computer Science                            Communication
# 4          Matric          Business                            Data Analysis
# 5          Matric              Arts                               Counseling
# 6          Matric  Computer Science            MS Office, Financial Analysis
# 7          Matric           Finance                               Counseling
# 8          Matric          Business               Financial Analysis, Python
# 9    Intermediate           Science                                MS Office
#
#          Certifications  CGPA/Percentage   Recommended Career
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Education Level     5000 non-null   object
#  1   Specialization      5000 non-null   object
#  2   Skills              5000 non-null   object
#  3   Certifications      4404 non-null   object
#  4   CGPA/Percentage     5000 non-null   int64
#  5   Recommended Career  5000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
#Sort by Education Level
df_sorted = df.sort_values(by='Education Level', ascending=False)
df_sorted.head(10)
# Out:
#      Education Level Specialization  \
# 2500             PhD        Finance
# 1849             PhD       Business
# 856              PhD        Finance
# 1841             PhD       Business
# 1843             PhD     Psychology
# 3141             PhD    Engineering
# 1847             PhD       Commerce
# 4129             PhD           Arts
# 4135             PhD        Finance
# 3144             PhD        Finance
#
#                                                Skills         Certifications  \
# 2500     Financial Analysis, Data Analysis, Marketing                    NaN
# 1849                                        MS Office  Google Data Analytics
# 856                       MS Office, Machine Learning          AWS Certified
# 1841  Financial Analysis, Machine Learning, MS Office      Digital Marketing
# 1843                               SQL, Data Analysis  Google Data Analytics
# 3141                                        MS Office          AWS Certified
# ...

# %%
#Sort by Education Level and only include those with PhD's
df_phd_sorted = df[df['Education Level'] == "PhD"].sort_values(by='Education Level', ascending=False)

df_phd_sorted
# Out:
#      Education Level Specialization  \
# 10               PhD     Psychology
# 3060             PhD       Business
# 3187             PhD       Commerce
# 3193             PhD        Science
# 3197             PhD     Psychology
# ...              ...            ...
# 1604             PhD           Arts
# 1610             PhD       Commerce
# 1613             PhD       Commerce
# 1617             PhD    Engineering
# 4998             PhD    Engineering
#
#                                                 Skills        Certifications  \
# 10                                  Financial Analysis     Digital Marketing
# 3060                          Machine Learning, Python     Digital Marketing
# 3187                                     Communication                   NaN
# 3193                                         MS Office  Mental Health Basics
# 3197  Data Analysis, Financial Analysis, Communication      Creative Writing
# ...

# %%
#Export to new excel file
df_phd_sorted.to_excel('C:/Users/matth/OneDrive/Desktop/DA/Personal Projects/data_cleaning/career_dataset_phd_sorted.xlsx', index=False)
