# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/matth/OneDrive/Desktop/DA/Personal Projects/data_cleaning/ig_post_performance_dataset.csv', encoding='cp1252')
df.head(10)
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
# 5         3884       2046           1214           329          43     74
# 6         2621       1543            599           333          25     22
# 7         3541       2071            628           500          60    135
# 8         3749       2384            857           248          49    155
# 9         4115       2609           1104           178          46    122
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# ...

# %%
df_new = df.drop(columns=['Caption', 'Hashtags'])

# %%
df_new
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows
# ...

# %%
#Rename Columns for SQL Compatibility
df_new = df_new.rename(columns={
    'From Home': 'from_home',
    'From Hashtags': 'from_hashtags',
    'From Explore': 'from_explore',
    'From Other': 'from_other',
    'Profile Visits': 'profile_visits',
    'Follows': 'follows'
})

# %%
df_new
# Out:
#      impressions  from_home  from_hashtags  from_explore  from_other  saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      comments  shares  likes  profile_visits  follows
# ...

# %%
df_new = df_new.drop_duplicates()

# %%
df_new
# Out:
#      impressions  from_home  from_hashtags  from_explore  from_other  saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      comments  shares  likes  profile_visits  follows
# ...

# %%
#Export Cleaned DataFrame to CSV
df_new.to_csv('C:/Users/matth/OneDrive/Desktop/DA/Personal Projects/data_cleaning/ig_post_performance_cleaned.csv', index=False)
print("Cleaned data exported successfully.")
# Out:
# Cleaned data exported successfully.
